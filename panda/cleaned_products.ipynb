# %%
import pandas as pd

df = pd.read_csv("../data/df_Products.csv")
df.head()
# Out:
#      product_id     product_category_name  product_weight_g  \
# 0  90K0C1fIyQUf                      toys             491.0
# 1  qejhpMGGVcsl             watches_gifts             440.0
# 2  qUS5d2pEAyxJ  costruction_tools_garden            2200.0
# 3  639iGvMyv0De                      toys            1450.0
# 4  1lycYGcsic2F                      toys             300.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               19.0               12.0              16.0
# 1               18.0               14.0              17.0
# 2               16.0               16.0              16.0
# 3               68.0                3.0              48.0
# 4               17.0                4.0              12.0

# %%
df.shape
# Out:
# (89316, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             89316 non-null  object
#  1   product_category_name  89008 non-null  object
#  2   product_weight_g       89301 non-null  float64
#  3   product_length_cm      89301 non-null  float64
#  4   product_height_cm      89301 non-null  float64
#  5   product_width_cm       89301 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 4.1+ MB

# %%
df.isnull().sum()
# Out:
# product_id                 0
# product_category_name    308
# product_weight_g          15
# product_length_cm         15
# product_height_cm         15
# product_width_cm          15
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(61865)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["product_category_name"] = df["product_category_name"].fillna("Unknown")

# %%
df["product_weight_g"] = df["product_weight_g"].fillna("Unknown")

# %%
df["product_length_cm"] = df["product_length_cm"].fillna("Unknown")

# %%
df["product_height_cm"] = df["product_height_cm"].fillna("Unknown")

# %%
df["product_width_cm"] = df["product_width_cm"].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_category_name    0
# product_weight_g         0
# product_length_cm        0
# product_height_cm        0
# product_width_cm         0
# dtype: int64

# %%
df.shape
# Out:
# (27451, 6)
