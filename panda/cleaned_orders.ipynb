# %%
import pandas as pd

df = pd.read_csv("../data/df_Orders.csv")
df.head()
# Out:
#        order_id   customer_id order_status order_purchase_timestamp  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3  bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4  Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
#
#      order_approved_at order_delivered_timestamp order_estimated_delivery_date
# 0  2017-10-22 19:14:13       2017-10-26 22:19:52                    2017-11-09
# 1  2018-06-20 22:20:20       2018-07-03 22:51:22                    2018-07-24
# 2  2018-02-17 16:15:35       2018-02-27 01:29:50                    2018-03-08
# 3  2018-08-18 18:15:16       2018-08-27 20:03:51                    2018-09-19
# 4  2017-12-22 17:31:31       2018-01-05 19:22:49                    2018-01-18

# %%
df.shape
# Out:
# (89316, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       89316 non-null  object
#  1   customer_id                    89316 non-null  object
#  2   order_status                   89316 non-null  object
#  3   order_purchase_timestamp       89316 non-null  object
#  4   order_approved_at              89307 non-null  object
#  5   order_delivered_timestamp      87427 non-null  object
#  6   order_estimated_delivery_date  89316 non-null  object
# dtypes: object(7)
# memory usage: 4.8+ MB

# %%
df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   9
# order_delivered_timestamp        1889
# order_estimated_delivery_date       0
# dtype: int64

# %%
df["order_status"].value_counts()
# Out:
# order_status
# delivered      87428
# shipped          936
# canceled         409
# processing       273
# invoiced         266
# unavailable        2
# approved           2
# Name: count, dtype: int64

# %%
df[df["order_delivered_timestamp"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# shipped        936
# canceled       404
# processing     273
# invoiced       266
# delivered        6
# unavailable      2
# approved         2
# Name: count, dtype: int64

# %%
df[df["order_approved_at"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# delivered    9
# Name: count, dtype: int64

# %%
df[df["order_approved_at"].isnull()]
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 10788  4Itts2TBUQzs  Z3dI7uRBfJOD    delivered      2017-02-17 13:05:55
# 16137  6MPB830Ufh0n  SOtqXN1MqcLj    delivered      2017-02-17 17:21:55
# 28951  lqW95yj4n1Qd  jCPmhkcyVR1z    delivered      2017-02-18 15:52:27
# 30494  dn1i9D4DFVZ2  Es95IGZCDDXy    delivered      2017-02-17 15:53:27
# 41752  vBZCEuCG9Hf1  zHEH7vdeO6UZ    delivered      2017-02-18 11:04:19
# 42772  PXwPIjmXCehX  gjKhFw8AFnW1    delivered      2017-02-18 16:48:35
# 47768  Yg9HDkWtA3Q3  GFg4QWN26cLs    delivered      2017-02-19 01:28:47
# 59434  hynO4uEubWbe  QdQBjy8APVMg    delivered      2017-02-18 14:40:00
# 65247  Uso7EoEPMrLU  rKJOxQc2PTfc    delivered      2017-01-19 22:26:59
#
#       order_approved_at order_delivered_timestamp  \
# 10788               NaN       2017-03-02 11:09:19
# 16137               NaN       2017-03-03 12:16:03
# 28951               NaN       2017-03-07 13:57:47
# ...

# %%
(df.isnull().sum() / len(df) * 100).round(2)
# Out:
# order_id                         0.00
# customer_id                      0.00
# order_status                     0.00
# order_purchase_timestamp         0.00
# order_approved_at                0.01
# order_delivered_timestamp        2.11
# order_estimated_delivery_date    0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["order_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_timestamp",
    "order_estimated_delivery_date"
]

for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
df.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_timestamp        datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
df[df["order_delivered_timestamp"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# shipped        936
# canceled       404
# processing     273
# invoiced       266
# delivered        6
# unavailable      2
# approved         2
# Name: count, dtype: int64

# %%
df[df["order_status"].eq("delivered") &
   df["order_delivered_timestamp"].isnull()]
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 4254   t5kBjEdw3z8t  ZeIXZ7BBF5PP    delivered      2017-11-28 17:44:07
# 13268  BxxG20QRNt7K  RWhfv6bIMVsQ    delivered      2018-06-20 06:58:43
# 30892  yRSiD6TjWuMp  WrJg7MJuozgD    delivered      2018-07-01 22:05:55
# 65263  1XWJAxXBtYuW  Z5AHwQM14J3A    delivered      2018-06-08 12:09:39
# 65525  H6OIR9EVCoos  53rYCxN5t4tp    delivered      2018-06-27 16:09:12
# 67317  EznMwXRSIZcm  RMR2x4OEJS2K    delivered      2018-07-01 17:05:11
#
#         order_approved_at order_delivered_timestamp  \
# 4254  2017-11-28 17:56:40                       NaT
# 13268 2018-06-20 07:19:05                       NaT
# 30892 2018-07-01 22:15:14                       NaT
# 65263 2018-06-08 12:36:39                       NaT
# 65525 2018-06-27 16:29:30                       NaT
# 67317 2018-07-01 17:15:12                       NaT
#
#       order_estimated_delivery_date
# 4254                     2017-12-18
# ...

# %%
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_timestamp",
    "order_estimated_delivery_date"
]

for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
df.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_timestamp        datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
(df["order_approved_at"] < df["order_purchase_timestamp"]).sum()
# Out:
# np.int64(0)

# %%
(df["order_delivered_timestamp"] < df["order_purchase_timestamp"]).sum()
# Out:
# np.int64(0)

# %%
(df["order_estimated_delivery_date"] <
 df["order_purchase_timestamp"]).sum()
# Out:
# np.int64(0)

# %%
df[df["order_status"].eq("delivered") &
   df["order_delivered_timestamp"].isnull()]
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 4254   t5kBjEdw3z8t  ZeIXZ7BBF5PP    delivered      2017-11-28 17:44:07
# 13268  BxxG20QRNt7K  RWhfv6bIMVsQ    delivered      2018-06-20 06:58:43
# 30892  yRSiD6TjWuMp  WrJg7MJuozgD    delivered      2018-07-01 22:05:55
# 65263  1XWJAxXBtYuW  Z5AHwQM14J3A    delivered      2018-06-08 12:09:39
# 65525  H6OIR9EVCoos  53rYCxN5t4tp    delivered      2018-06-27 16:09:12
# 67317  EznMwXRSIZcm  RMR2x4OEJS2K    delivered      2018-07-01 17:05:11
#
#         order_approved_at order_delivered_timestamp  \
# 4254  2017-11-28 17:56:40                       NaT
# 13268 2018-06-20 07:19:05                       NaT
# 30892 2018-07-01 22:15:14                       NaT
# 65263 2018-06-08 12:36:39                       NaT
# 65525 2018-06-27 16:29:30                       NaT
# 67317 2018-07-01 17:15:12                       NaT
#
#       order_estimated_delivery_date  delivery_delay_days
# ...

# %%
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_timestamp",
    "order_estimated_delivery_date"
]

for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
(df["order_approved_at"] < df["order_purchase_timestamp"]).sum()
# Out:
# np.int64(0)

# %%
(df["order_delivered_timestamp"] < df["order_purchase_timestamp"]).sum()
# Out:
# np.int64(0)

# %%
(df["order_estimated_delivery_date"] <
 df["order_purchase_timestamp"]).sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_timestamp        datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# delivery_delay_days                     float64
# dtype: object

# %%
df["delivery_delay_days"].describe()
# Out:
# count    87427.000000
# mean       -12.132442
# std         10.041470
# min       -147.000000
# 25%        -17.000000
# 50%        -13.000000
# 75%         -7.000000
# max        188.000000
# Name: delivery_delay_days, dtype: float64

# %%
df["delivery_delay_days"].isnull().sum()
# Out:
# np.int64(1889)

# %%
df["delivery_delay_days"].head(10)
# Out:
# 0   -14.0
# 1   -21.0
# 2    -9.0
# 3   -23.0
# 4   -13.0
# 5   -11.0
# 6    -9.0
# 7    18.0
# 8    -3.0
# 9   -20.0
# Name: delivery_delay_days, dtype: float64

# %%
df[
    (df["order_status"] == "delivered") &
    (df["order_delivered_timestamp"].isnull())
]
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 4254   t5kBjEdw3z8t  ZeIXZ7BBF5PP    delivered      2017-11-28 17:44:07
# 13268  BxxG20QRNt7K  RWhfv6bIMVsQ    delivered      2018-06-20 06:58:43
# 30892  yRSiD6TjWuMp  WrJg7MJuozgD    delivered      2018-07-01 22:05:55
# 65263  1XWJAxXBtYuW  Z5AHwQM14J3A    delivered      2018-06-08 12:09:39
# 65525  H6OIR9EVCoos  53rYCxN5t4tp    delivered      2018-06-27 16:09:12
# 67317  EznMwXRSIZcm  RMR2x4OEJS2K    delivered      2018-07-01 17:05:11
#
#         order_approved_at order_delivered_timestamp  \
# 4254  2017-11-28 17:56:40                       NaT
# 13268 2018-06-20 07:19:05                       NaT
# 30892 2018-07-01 22:15:14                       NaT
# 65263 2018-06-08 12:36:39                       NaT
# 65525 2018-06-27 16:29:30                       NaT
# 67317 2018-07-01 17:15:12                       NaT
#
#       order_estimated_delivery_date  delivery_delay_days
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["order_status"].value_counts()
# Out:
# order_status
# delivered      87428
# shipped          936
# canceled         409
# processing       273
# invoiced         266
# unavailable        2
# approved           2
# Name: count, dtype: int64

# %%
df["customer_id"].isin(df["customer_id"]).value_counts()
# Out:
# customer_id
# True    89316
# Name: count, dtype: int64

# %%
df["delivery_delay_days"] = (
    df["order_delivered_timestamp"]
    - df["order_estimated_delivery_date"]
).dt.days

# %%
# 1. Investigate 6 delivered orders with missing delivery date
df[
    (df["order_status"] == "delivered") &
    (df["order_delivered_timestamp"].isnull())
]
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 4254   t5kBjEdw3z8t  ZeIXZ7BBF5PP    delivered      2017-11-28 17:44:07
# 13268  BxxG20QRNt7K  RWhfv6bIMVsQ    delivered      2018-06-20 06:58:43
# 30892  yRSiD6TjWuMp  WrJg7MJuozgD    delivered      2018-07-01 22:05:55
# 65263  1XWJAxXBtYuW  Z5AHwQM14J3A    delivered      2018-06-08 12:09:39
# 65525  H6OIR9EVCoos  53rYCxN5t4tp    delivered      2018-06-27 16:09:12
# 67317  EznMwXRSIZcm  RMR2x4OEJS2K    delivered      2018-07-01 17:05:11
#
#         order_approved_at order_delivered_timestamp  \
# 4254  2017-11-28 17:56:40                       NaT
# 13268 2018-06-20 07:19:05                       NaT
# 30892 2018-07-01 22:15:14                       NaT
# 65263 2018-06-08 12:36:39                       NaT
# 65525 2018-06-27 16:29:30                       NaT
# 67317 2018-07-01 17:15:12                       NaT
#
#       order_estimated_delivery_date  delivery_delay_days
# ...

# %%
# 2. Duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 3. Duplicate order IDs
df["order_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
# 4. Orders → Customers relationship
df["customer_id"].isin(df["customer_id"]).value_counts()
# Out:
# customer_id
# True    89316
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_timestamp        datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# delivery_delay_days                     float64
# dtype: object

# %%
df = df.drop(columns=["delivery_delay_days"])

# %%
df.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_timestamp        datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
df.to_csv(
    "cleaned_orders.csv",
    index=False
)
